# %%
import pandas as pd

# %%
data = pd.read_csv("aggregated_results.csv")
data
# Out:
#       Unnamed: 0                       Sample name  AA amplicon number  \
# 0              0                5637_URINARY_TRACT                 1.0
# 1              1                5637_URINARY_TRACT                 1.0
# 2              2                         59M_OVARY                 1.0
# 3              3                         59M_OVARY                 2.0
# 4              4                         59M_OVARY                 2.0
# ...          ...                               ...                 ...
# 1235        1235                       A2780_OVARY                 NaN
# 1236        1236  ISHIKAWAHERAKLIO02ER_ENDOMETRIUM                 NaN
# 1237        1237                     HPAC_PANCREAS                 NaN
# 1238        1238             SW948_LARGE_INTESTINE                 NaN
# 1239        1239                 PANC1005_PANCREAS                 NaN
#
#                                     Feature ID      Classification  \
# ...

# %%
data2 = data[data["Classification"]=="ecDNA"]
data2
# Out:
#       Unnamed: 0         Sample name  AA amplicon number  \
# 0              0  5637_URINARY_TRACT                 1.0
# 1              1  5637_URINARY_TRACT                 1.0
# 3              3           59M_OVARY                 2.0
# 4              4           59M_OVARY                 2.0
# 8              8       8305C_THYROID                 1.0
# ...          ...                 ...                 ...
# 1139        1139      UACC812_BREAST                 1.0
# 1141        1141      UACC812_BREAST                 3.0
# 1147        1147      UACC893_BREAST                 6.0
# 1150        1150      UACC893_BREAST                 9.0
# 1157        1157        ZR751_BREAST                 2.0
#
#                                 Feature ID Classification  \
# 0     5637_URINARY_TRACT_amplicon1_ecDNA_1          ecDNA
# 1     5637_URINARY_TRACT_amplicon1_ecDNA_2          ecDNA
# 3              59M_OVARY_amplicon2_ecDNA_2          ecDNA
# ...

# %%
data3 = data2[data2['All genes']=="[]"]
data3
# Out:
#       Unnamed: 0                               Sample name  \
# 12            12  A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 44            44                              BT474_BREAST
# 57            57                              CAKI1_KIDNEY
# 59            59                             CAL120_BREAST
# 64            64                             CAL120_BREAST
# 76            76                               CAOV3_OVARY
# 138          138                               DMS114_LUNG
# 197          197                            EFM192A_BREAST
# 259          259                                 HARA_LUNG
# 318          318                            HCC1937_BREAST
# 346          346                            HCC2157_BREAST
# 372          372                               HCC827_LUNG
# 381          381                                HCC95_LUNG
# 382          382                                HCC95_LUNG
# 400          400                             HGC27_STOMACH
# ...

# %%
data3.to_csv('processed_results.csv')

# %%
data2.to_csv("all_results.csv")

# %%
filtered_df = data2[data2['Location'].str.contains('chr3')]
#filtered_df = filtered_df[~filtered_df['All genes'].str.contains('[]')]
filtered_data2 = filtered_df[filtered_df['All genes'] != '[]']
# Print the filtered DataFrame
filtered_data2
# Out:
#       Unnamed: 0                               Sample name  \
# 1              1                        5637_URINARY_TRACT
# 14            14  A3KAW_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 23            23                              AU565_BREAST
# 38            38                               BT20_BREAST
# 75            75                               CAOV3_OVARY
# 83            83                              CHAGOK1_LUNG
# 89            89                   COLO201_LARGE_INTESTINE
# 98            98                               CORL23_LUNG
# 236          236                               FUOV1_OVARY
# 309          309                            HCC1599_BREAST
# 356          356                              HCC38_BREAST
# 429          429                                JHH1_LIVER
# 446          446                           KATOIII_STOMACH
# 488          488                         KYSE30_OESOPHAGUS
# 567          567                           MDAMB453_BREAST
# ...
