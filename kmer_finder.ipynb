# %%
def FrequentWords(Text, k):
    
    freqMap = {}
    n = len(Text)
   
    for i in range(n-k+1):
        Pattern = Text[i:k+i]
        if Pattern not in freqMap:
            freqMap[Pattern] = 1
        else:
            freqMap[Pattern]=freqMap.get(Pattern)+1
      
    sortedFreq = sorted(freqMap.items(), key=lambda x: x[1], reverse=True)
    topKmers = [(kmer, count) for kmer, count in sortedFreq[:3]]
    
    return topKmers

# %%
def eval(databaselen,seqlen):
    return databaselen*seqlen*((0.25)**seqlen)

# %%
k = 5
file = open("chr3CAOV3.txt","r")
data = file.readlines()
genome = data[0]

output1 = FrequentWords(genome,k)
output1
# Out:
# [('AAAAA', 161), ('AAAAT', 91), ('AGAAA', 88)]

# %%
for i in range(5,16):
    file = open("chr3CAOV3.txt","r")
    data = file.readlines()
    genome = data[0]

    output1 = FrequentWords(genome,i)
    print("For i = " + str(i) + ",the top three kmers are: "+ "\n")
    for output in output1:
    
        print(output)
    print("E-value: " + str(eval(len(genome),i)))
# Out:
# For i = 5,the top three kmers are:
#
# ('AAAAA', 161)
# ('AAAAT', 91)
# ('AGAAA', 88)
# E-value: 92.7490234375
# For i = 6,the top three kmers are:
#
# ('AAAAAA', 71)
# ('CACACA', 41)
# ('ACACAC', 38)
# E-value: 27.82470703125
# For i = 7,the top three kmers are:
#
# ('AAAAAAA', 44)
# ('ACACACA', 32)
# ('CACACAC', 24)
# E-value: 8.11553955078125
# For i = 8,the top three kmers are:
#
# ('AAAAAAAA', 31)
# ('CACACACA', 23)
# ('ACACACAC', 22)
# E-value: 2.3187255859375
# For i = 9,the top three kmers are:
#
# ('AAAAAAAAA', 25)
# ('ACACACACA', 22)
# ('CACACACAC', 18)
# E-value: 0.6521415710449219
# For i = 10,the top three kmers are:
#
# ('AAAAAAAAAA', 22)
# ('ACACACACAC', 18)
# ('CACACACACA', 18)
# E-value: 0.1811504364013672
# For i = 11,the top three kmers are:
#
# ('AAAAAAAAAAA', 20)
# ('ACACACACACA', 18)
# ('CACACACACAC', 15)
# E-value: 0.04981637001037598
# For i = 12,the top three kmers are:
#
# ('AAAAAAAAAAAA', 18)
# ('ACACACACACAC', 15)
# ('CACACACACACA', 15)
# ...

# %%
for i in range(5,16):
    file = open("chr3HLT.txt","r")
    data = file.readlines()
    genome = data[0]

    output1 = FrequentWords(genome,i)
    print("For i = " + str(i) + ",the top three kmers are: "+ "\n")
    for output in output1:
    
        print(output)
    print("E-value: " + str(eval(len(genome),i)))
# Out:
# For i = 5,the top three kmers are:
#
# ('AAAAA', 722)
# ('TTTTT', 482)
# ('AAAAT', 408)
# E-value: 452.2802734375
# For i = 6,the top three kmers are:
#
# ('AAAAAA', 375)
# ('TTTTTT', 200)
# ('AAAAAT', 159)
# E-value: 135.68408203125
# For i = 7,the top three kmers are:
#
# ('AAAAAAA', 228)
# ('TTTTTTT', 106)
# ('AAAAAAT', 70)
# E-value: 39.57452392578125
# For i = 8,the top three kmers are:
#
# ('AAAAAAAA', 161)
# ('TTTTTTTT', 59)
# ('AAAAAAAT', 30)
# E-value: 11.3070068359375
# For i = 9,the top three kmers are:
#
# ('AAAAAAAAA', 125)
# ('TTTTTTTTT', 33)
# ('TGTTTGTTT', 22)
# E-value: 3.180095672607422
# For i = 10,the top three kmers are:
#
# ('AAAAAAAAAA', 102)
# ('TTTTTTTTTT', 21)
# ('TTGTTTGTTT', 19)
# E-value: 0.8833599090576172
# For i = 11,the top three kmers are:
#
# ('AAAAAAAAAAA', 85)
# ('TTTGTTTGTTT', 18)
# ('TTTTTTTTTTT', 17)
# E-value: 0.24292397499084473
# For i = 12,the top three kmers are:
#
# ('AAAAAAAAAAAA', 71)
# ('TGTTTGTTTGTT', 15)
# ('GTTTGTTTGTTT', 15)
# ...

# %%
#chr3MFE280.txt

for i in range(5,16):
    file = open("chr3MFE280.txt","r")
    data = file.readlines()
    genome = data[0]

    output1 = FrequentWords(genome,i)
    print("For i = " + str(i) + ",the top three kmers are: "+ "\n")
    for output in output1:
    
        print(output)
    print("E-value: " + str(eval(len(genome),i)))
# Out:
# For i = 5,the top three kmers are:
#
# ('AAAAA', 506)
# ('TTTTT', 363)
# ('AAAAT', 269)
# E-value: 258.4326171875
# For i = 6,the top three kmers are:
#
# ('AAAAAA', 262)
# ('TTTTTT', 201)
# ('AAAAAT', 112)
# E-value: 77.52978515625
# For i = 7,the top three kmers are:
#
# ('AAAAAAA', 154)
# ('TTTTTTT', 139)
# ('AAAAAAT', 49)
# E-value: 22.61285400390625
# For i = 8,the top three kmers are:
#
# ('AAAAAAAA', 107)
# ('TTTTTTTT', 106)
# ('TTTTAAAA', 25)
# E-value: 6.4608154296875
# For i = 9,the top three kmers are:
#
# ('TTTTTTTTT', 84)
# ('AAAAAAAAA', 83)
# ('ACACACACA', 17)
# E-value: 1.8171043395996094
# For i = 10,the top three kmers are:
#
# ('AAAAAAAAAA', 67)
# ('TTTTTTTTTT', 66)
# ('CACACACACA', 14)
# E-value: 0.5047512054443359
# For i = 11,the top three kmers are:
#
# ('AAAAAAAAAAA', 53)
# ('TTTTTTTTTTT', 51)
# ('ACACACACACA', 13)
# E-value: 0.13880658149719238
# For i = 12,the top three kmers are:
#
# ('TTTTTTTTTTTT', 41)
# ('AAAAAAAAAAAA', 41)
# ('CACACACACACA', 12)
# ...

# %%
#chr3MFE319.txt
for i in range(5,16):
    file = open("chr3MFE319.txt","r")
    data = file.readlines()
    genome = data[0]

    output1 = FrequentWords(genome,i)
    print("For i = " + str(i) + ",the top three kmers are: "+ "\n")
    for output in output1:
    
        print(output)
    print("E-value: " + str(eval(len(genome),i)))
# Out:
# For i = 5,the top three kmers are:
#
# ('AAAAA', 1001)
# ('TTTTT', 965)
# ('AAAAT', 699)
# E-value: 653.0029296875
# For i = 6,the top three kmers are:
#
# ('AAAAAA', 495)
# ('TTTTTT', 420)
# ('ATTTTT', 280)
# E-value: 195.90087890625
# For i = 7,the top three kmers are:
#
# ('AAAAAAA', 289)
# ('TTTTTTT', 239)
# ('AAAGAAA', 125)
# E-value: 57.13775634765625
# For i = 8,the top three kmers are:
#
# ('AAAAAAAA', 197)
# ('TTTTTTTT', 168)
# ('AAAGAAAA', 53)
# E-value: 16.3250732421875
# For i = 9,the top three kmers are:
#
# ('AAAAAAAAA', 145)
# ('TTTTTTTTT', 128)
# ('AGAAAGAAA', 35)
# E-value: 4.591426849365234
# For i = 10,the top three kmers are:
#
# ('AAAAAAAAAA', 114)
# ('TTTTTTTTTT', 104)
# ('AAAGAAAGAA', 29)
# E-value: 1.2753963470458984
# For i = 11,the top three kmers are:
#
# ('TTTTTTTTTTT', 90)
# ('AAAAAAAAAAA', 90)
# ('AAGAAAGAAAG', 25)
# E-value: 0.35073399543762207
# For i = 12,the top three kmers are:
#
# ('TTTTTTTTTTTT', 77)
# ('AAAAAAAAAAAA', 73)
# ('AAGAAAGAAAGA', 22)
# ...

# %%
#chr3SKOV3_OVARY.txt
for i in range(5,16):
    file = open("chr3SKOV3_OVARY.txt","r")
    data = file.readlines()
    genome = data[0]

    output1 = FrequentWords(genome,i)
    print("For i = " + str(i) + ",the top three kmers are: "+ "\n")
    for output in output1:
    
        print(output)
    print("E-value: " + str(eval(len(genome),i)))
# Out:
# For i = 5,the top three kmers are:
#
# ('AAAAA', 1102)
# ('TTTTT', 670)
# ('AAAAT', 641)
# E-value: 747.1484375
# For i = 6,the top three kmers are:
#
# ('AAAAAA', 540)
# ('TTTTTT', 298)
# ('AAAAAT', 252)
# E-value: 224.14453125
# For i = 7,the top three kmers are:
#
# ('AAAAAAA', 334)
# ('TTTTTTT', 153)
# ('AAATAAA', 109)
# E-value: 65.37548828125
# For i = 8,the top three kmers are:
#
# ('AAAAAAAA', 236)
# ('TTTTTTTT', 91)
# ('ATATATAT', 84)
# E-value: 18.6787109375
# For i = 9,the top three kmers are:
#
# ('AAAAAAAAA', 185)
# ('TATATATAT', 72)
# ('ATATATATA', 68)
# E-value: 5.253387451171875
# For i = 10,the top three kmers are:
#
# ('AAAAAAAAAA', 151)
# ('ATATATATAT', 63)
# ('TATATATATA', 60)
# E-value: 1.4592742919921875
# For i = 11,the top three kmers are:
#
# ('AAAAAAAAAAA', 131)
# ('TATATATATAT', 56)
# ('ACACACACACA', 54)
# E-value: 0.40130043029785156
# For i = 12,the top three kmers are:
#
# ('AAAAAAAAAAAA', 113)
# ('CACACACACACA', 52)
# ('ACACACACACAC', 49)
# ...

# %%
#chr3CHAGOK1_LUNG.txt
for i in range(5,16):
    file = open("chr3CHAGOK1_LUNG.txt","r")
    data = file.readlines()
    genome = data[0]

    output1 = FrequentWords(genome,i)
    print("For i = " + str(i) + ",the top three kmers are: "+ "\n")
    for output in output1:
    
        print(output)
    print("E-value: " + str(eval(len(genome),i)))
# Out:
# For i = 5,the top three kmers are:
#
# ('AAAAA', 11700)
# ('TTTTT', 10459)
# ('AAAAT', 6490)
# E-value: 6701.5673828125
# For i = 6,the top three kmers are:
#
# ('AAAAAA', 6212)
# ('TTTTTT', 5485)
# ('AAAAAT', 2683)
# E-value: 2010.47021484375
# For i = 7,the top three kmers are:
#
# ('AAAAAAA', 4087)
# ('TTTTTTT', 3577)
# ('TTTTAAA', 1040)
# E-value: 586.3871459960938
# For i = 8,the top three kmers are:
#
# ('AAAAAAAA', 3038)
# ('TTTTTTTT', 2630)
# ('TTTTAAAA', 526)
# E-value: 167.5391845703125
# For i = 9,the top three kmers are:
#
# ('AAAAAAAAA', 2430)
# ('TTTTTTTTT', 2105)
# ('TGTGTGTGT', 364)
# E-value: 47.12039566040039
# For i = 10,the top three kmers are:
#
# ('AAAAAAAAAA', 1987)
# ('TTTTTTTTTT', 1733)
# ('GTGTGTGTGT', 305)
# E-value: 13.088998794555664
# For i = 11,the top three kmers are:
#
# ('AAAAAAAAAAA', 1643)
# ('TTTTTTTTTTT', 1453)
# ('TGTGTGTGTGT', 283)
# E-value: 3.5994746685028076
# For i = 12,the top three kmers are:
#
# ('AAAAAAAAAAAA', 1362)
# ...

# %%
#chr3AU565_BREAST.txt
for i in range(5,16):
    file = open("chr3CHAGOK1_LUNG.txt","r")
    data = file.readlines()
    genome = data[0]

    output1 = FrequentWords(genome,i)
    print("For i = " + str(i) + ",the top three kmers are: "+ "\n")
    for output in output1:
    
        print(output)
    print("E-value: " + str(eval(len(genome),i)))
